# %%
# instancias dadas para o trabalho
datasets = [
    "eil51", "berlin52", "st70", "eil76", "pr76", "rat99", 
    "kroA100", "kroB100", "kroC100", "kroD100", "kroE100", "rd100",
    "eil101", "lin105", "pr107", "pr124", "bier127", "ch130",
    "pr136", "pr144", "ch150", "kroA150", "kroB150", "pr152",
    "u159", "rat195", "d198", "kroA200", "kroB200", "ts225",
    "tsp225", "pr226", "gil262", "pr264", "a280", "pr299",
    "lin318", "linhp318", "rd400", "fl417", "pr439", "pcb442",
    "d493", "u574", "rat575", "p654", "d657", "u724",
    "rat783", "pr1002", "u1060", "vm1084", "pcb1173", "d1291",
    "rl1304", "rl1323", "nrw1379", "fl1400", "u1432", "fl1577",
    "d1655", "vm1748", "u1817", "rl1889", "d2103", "u2152",
    "u2319", "pr2392", "pcb3038", "fl3795", "fnl4461", "rl5915",
    "rl5934", "rl11849", "usa13509", "brd14051", "d15112", "d18512"
]

# %%
import tarfile

# Nome do arquivo tar principal
nome_arquivo_tar_principal = 'ALL_tsp.tar.gz'
arquivos_para_extrair = [(i+'.tsp.gz', i+'.opt.tour.gz') for i in datasets]

# Extrair o arquivo tar principal
with tarfile.open(nome_arquivo_tar_principal, 'r') as tar:

    # Extrair apenas os membros selecionados
    for membro in arquivos_para_extrair:
        try: 
            tar.extract(membro[0], './instancias/')
        except:
            print(f"O arquivo '{membro[0]}' não foi encontrado.")
        try: 
            tar.extract(membro[1], './solucoes/')
        except:
            print(f"O arquivo '{membro[1]}' não foi encontrado.")
# Out:
# O arquivo 'rat99.opt.tour.gz' não foi encontrado.
# O arquivo 'kroB100.opt.tour.gz' não foi encontrado.
# O arquivo 'kroE100.opt.tour.gz' não foi encontrado.
# O arquivo 'pr107.opt.tour.gz' não foi encontrado.
# O arquivo 'pr124.opt.tour.gz' não foi encontrado.
# O arquivo 'bier127.opt.tour.gz' não foi encontrado.
# O arquivo 'pr136.opt.tour.gz' não foi encontrado.
# O arquivo 'pr144.opt.tour.gz' não foi encontrado.
# O arquivo 'kroA150.opt.tour.gz' não foi encontrado.
# O arquivo 'kroB150.opt.tour.gz' não foi encontrado.
# O arquivo 'pr152.opt.tour.gz' não foi encontrado.
# O arquivo 'u159.opt.tour.gz' não foi encontrado.
# O arquivo 'rat195.opt.tour.gz' não foi encontrado.
# O arquivo 'd198.opt.tour.gz' não foi encontrado.
# O arquivo 'kroA200.opt.tour.gz' não foi encontrado.
# O arquivo 'kroB200.opt.tour.gz' não foi encontrado.
# O arquivo 'ts225.opt.tour.gz' não foi encontrado.
# O arquivo 'pr226.opt.tour.gz' não foi encontrado.
# O arquivo 'gil262.opt.tour.gz' não foi encontrado.
# O arquivo 'pr264.opt.tour.gz' não foi encontrado.
# O arquivo 'pr299.opt.tour.gz' não foi encontrado.
# O arquivo 'lin318.opt.tour.gz' não foi encontrado.
# O arquivo 'linhp318.opt.tour.gz' não foi encontrado.
# O arquivo 'rd400.opt.tour.gz' não foi encontrado.
# O arquivo 'fl417.opt.tour.gz' não foi encontrado.
# O arquivo 'pr439.opt.tour.gz' não foi encontrado.
# O arquivo 'd493.opt.tour.gz' não foi encontrado.
# O arquivo 'u574.opt.tour.gz' não foi encontrado.
# O arquivo 'rat575.opt.tour.gz' não foi encontrado.
# O arquivo 'p654.opt.tour.gz' não foi encontrado.
# O arquivo 'd657.opt.tour.gz' não foi encontrado.
# O arquivo 'u724.opt.tour.gz' não foi encontrado.
# O arquivo 'rat783.opt.tour.gz' não foi encontrado.
# O arquivo 'u1060.opt.tour.gz' não foi encontrado.
# O arquivo 'vm1084.opt.tour.gz' não foi encontrado.
# O arquivo 'pcb1173.opt.tour.gz' não foi encontrado.
# O arquivo 'd1291.opt.tour.gz' não foi encontrado.
# O arquivo 'rl1304.opt.tour.gz' não foi encontrado.
# O arquivo 'rl1323.opt.tour.gz' não foi encontrado.
# O arquivo 'nrw1379.opt.tour.gz' não foi encontrado.
# O arquivo 'fl1400.opt.tour.gz' não foi encontrado.
# O arquivo 'u1432.opt.tour.gz' não foi encontrado.
# O arquivo 'fl1577.opt.tour.gz' não foi encontrado.
# O arquivo 'd1655.opt.tour.gz' não foi encontrado.
# O arquivo 'vm1748.opt.tour.gz' não foi encontrado.
# O arquivo 'u1817.opt.tour.gz' não foi encontrado.
# O arquivo 'rl1889.opt.tour.gz' não foi encontrado.
# O arquivo 'd2103.opt.tour.gz' não foi encontrado.
# O arquivo 'u2152.opt.tour.gz' não foi encontrado.
# O arquivo 'u2319.opt.tour.gz' não foi encontrado.
# O arquivo 'pcb3038.opt.tour.gz' não foi encontrado.
# O arquivo 'fl3795.opt.tour.gz' não foi encontrado.
# O arquivo 'fnl4461.opt.tour.gz' não foi encontrado.
# O arquivo 'rl5915.opt.tour.gz' não foi encontrado.
# O arquivo 'rl5934.opt.tour.gz' não foi encontrado.
# O arquivo 'rl11849.opt.tour.gz' não foi encontrado.
# O arquivo 'usa13509.opt.tour.gz' não foi encontrado.
# O arquivo 'brd14051.opt.tour.gz' não foi encontrado.
# O arquivo 'd15112.opt.tour.gz' não foi encontrado.
# O arquivo 'd18512.opt.tour.gz' não foi encontrado.
